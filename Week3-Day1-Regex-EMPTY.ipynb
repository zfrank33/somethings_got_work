# %% [markdown]
# # Regular Expressions

# %% [markdown]
# # Tasks today:
# 1) <b>Importing</b> <br>
# 2) <b>Using Regular Expressions</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) re.compile() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) re.match() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) re.findall() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
# 3) <b>Sets</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Integer Ranges <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Character Ranges <br>
# 4) <b>Counting Occurences</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) {x} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) {, x} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) {?} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) {*} <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) {+} <br>
# 5) <b>In-Class Exercise #1</b> <br>
# 6) <b>Escaping Characters</b> <br>
# 7) <b>Grouping</b> <br>
# 8) <b>In-Class Exercise #2</b> <br>
# 9) <b>Opening a File</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) open() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) with open() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) re.match() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) re.search() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Store the String in a Variable <br>
# 10) <b>Regex Project</b> <br>

# %% [markdown]
# ### Importing <br>
# <p>Regular Expressions are universal throughout most programming languages... They are generally imported through the module 're'.</p>

# %%
# import re

# %% [markdown]
# ### Using Regular Expressions <br>
# <p>Regular expressions give us the ability to search for patterns within text, strings, files, etc. They serve several uses, such as; security measures, searching, filtering, pattern recognition, and more...</p>

# %% [markdown]
# ##### RegEx Cheatsheet

# %% [raw]
# ########################
# # DO NOT RUN THIS CELL #
# ########################
#
# a, X, 9, < -- ordinary characters just match themselves exactly.
# . (a period) -- matches any single character except newline '\n'
# \w -- matches a "word" character: a letter or digit or underbar [a-zA-Z0-9_].
# \W -- matches any non-word character.
# \b -- matches word boundary (in between a word character and a non word character)
# \s -- matches a single whitespace character -- space, newline, return, tab
# \S -- matches any non-whitespace character.
# \t, \n, \r -- tab, newline, return
# \d -- matches any numeric digit [0-9]
# \D matches any non-numeric character.
# ^ -- matches the beginning of the string, or specify omition of certain characters
# $ -- matches the end of the string
# \ -- escapes special character.
# (x|y|z) matches exactly one of x, y or z.
# (x) in general is a remembered group. We can get the value of what matched by using the groups() method of the object returned by re.search.
# x? matches an optional x character (in other words, it matches an x zero or one times).
# x* matches x zero or more times.
# x+ matches x one or more times.
# x{m,n} matches an x character at least m times, but not more than n times.
# ?: matches an expression but do not capture it. Non capturing group.
# ?= matches a suffix but exclude it from capture. Positive lookahead.
# a(?=b) will match the "a" in "ab", but not the "a" in "ac"
# In other words, a(?=b) matches the "a" which is followed by the string 'b', without consuming what follows the a.
# ?! matches if suffix is absent. Negative look ahead.
# a(?!b) will match the "a" in "ac", but not the "a" in "ab"
# ?<= positive look behind
# [] matches for groupings of consecutive characters
# ?<! negative look behind
#
# ########################
# # DO NOT RUN THIS CELL #
# ########################

# %% [markdown]
# ##### re.compile()

# %%
# using compile, pre determines the string to be used in regular expression methods
pattern= re.compiler(r'abcd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\franc\OneDrive\Documents\coding_temple\Week3\Day1\Week3-Day1-Regex-EMPTY.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000008?line=0'>1</a> # using compile, pre determines the string to be used in regular expression methods
# ----> <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000008?line=1'>2</a> pattern= re.compiler(r'abcd')
#
# NameError: name 're' is not defined

# %% [markdown]
# ##### re.match()

# %%
search the begining of string for a pattern;
match=pattern.match('abcd1223')
print(match)
print(match.span())
#startr=match.span()[0}] and #stop=match.span()[1] in open line
start, stop = match.span()
data[start:stop]

# %% [markdown]
# ##### re.findall()

# %%
# return a list
finders=pattern.findall('123abcd abcd123 abcd')
print(finders)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\franc\OneDrive\Documents\coding_temple\Week3\Day1\Week3-Day1-Regex-EMPTY.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000013?line=0'>1</a> # return a list
# ----> <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000013?line=1'>2</a> finders=pattern.findall('123abcd abcd123 abcd')
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000013?line=2'>3</a> print(finders)
#
# NameError: name 'pattern' is not defined

# %% [markdown]
# ##### re.search()

# %%
#will find a single match anywhre in your string
random_string='123 123 234 abcd'
search=pattern.search(random my_string)
print(search)
# Out:
#   Input In [4]
#     search=pattern.search(random my_string)
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sets <br>
# <p>The following cells will allow you to use regular expressions to search for certain values within a range such as numbers 1 through 4.</p>

# %% [markdown]
# ##### [a-z] or [A-Z] - any lowercase/uppercase letters from a to z<br/>[^2] - anything that's not 2

# %% [markdown]
# ##### Integer Ranges

# %%
pattern_int=re.compiler(r'[0-7] [7-9]')
#any number 0-78 followed by 7-9
random_number=pattern_int.search('6783)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\franc\OneDrive\Documents\coding_temple\Week3\Day1\Week3-Day1-Regex-EMPTY.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000019?line=0'>1</a> pattern_int=re.compiler(r'[0-7] [7-9]')
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000019?line=1'>2</a> #any number 0-78 followed by 7-9
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/coding_temple/Week3/Day1/Week3-Day1-Regex-EMPTY.ipynb#ch0000019?line=2'>3</a> random_number=pattern_int.search('6783)')
#
# NameError: name 're' is not defined

# %% [markdown]
# random_number=pattern_int.findall('6783)')
# print(random_number)

# %% [markdown]
# ##### Character Ranges

# %%
pattern_char=re.compiler(r'[A-Z')

# %% [markdown]
# ### Counting Occurences

# %% [markdown]
# ##### {x} - something that occurs {num_of_times}

# %% [markdown]
# ##### {x, x} - something that occurs between x and x times

# %% [markdown]
# ##### ? - something that occurs 0 or 1 time

# %% [markdown]
# ##### * - something that occurs at least 0 times

# %% [markdown]
# ##### + - something that occurs at least once

# %% [markdown]
# ##### In-class exercise 1:
#
# Use a regular expression to find every number in the given string

# %%
my_string = "This string has 10909090 numbers, but it is only 1 string. I hope you solve this 2day."

# %% [markdown]
# ### Escaping Characters

# %% [markdown]
# ##### \w - look for any Unicode character<br/>\W - look for anything that isnt a Unicode character
#
# [History on Unicode](http://unicode.org/standard/WhatIsUnicode.html)
#
# [More on Unicode Characters](https://en.wikipedia.org/wiki/List_of_Unicode_characters)

# %%
pattern_1 = re.compiler(r'[\w] +')
pattern_2 = re.compiler(r'W[\]]+')
my_string="This is 1 sentence. With an,exclamation mark at the end!""

# %% [markdown]
# ##### \d - look for any digit 0-9<br/>\D - look for anything that isnt a digit

# %% [markdown]
# ##### \s - look for any white space<br/>\S - look for anything that isnt whitespace

# %%
pattern_1=re.compile(r'\s[a-z]+') whitespace
pattern_2=re.compile(r'\S[a-z]+') whitespace

# %% [markdown]
# ##### \b - look for boundaries or edges of a word<br/>\B - look for anything that isnt a boundary

# %% [markdown]
# ### Grouping

# %%
my_string = "Max Smith, aaron rodgers, Sam Darnold, LeBron James, Micheal Jordan, Kevin Durant, Patrick McCormick"
pattern= re.compiler(r'[A-Z][a-z')

# %% [markdown]
# ##### In-class Exercise 2:
#
# Write a function using regular expressions to find the domain name in the given email addresses (and return None for the invalid email addresses)<br><b>HINT: Use '|' for either or</b>

# %%
my_emails = ["jordanw@codingtemple.orgcom", "pocohontas1776@gmail.com", "helloworld@aol..com",
             "yourfavoriteband@g6.org", "@codingtemple.com"]

# You can also use the $ at the end of your compile expression -- this stops the search

#Expected output:
#jordanw@codingtemple.orgcom
#pocohontas1776@gmail.com
#None
#yourfavoriteband@g6.org
#None

email_pattern = re.compile(r'[\w\d]+@[a-z|\d]+\.[a-z]')

for email in my_emails:
    is_email = email_pattern.findall(email)
    if is_email:
        print(email)
    else:
        print('none')

# %% [markdown]
# ### Opening a File <br>
# <p>Python gives us a couple ways to import files, below are the two used most often.</p>

# %% [markdown]
# ##### open()

# %%
#NEVER DO THIS
file = open('.files/names.txt')
data = file .read()
print(data)
file.close()
type(data)

# %% [markdown]
# ##### with open()

# %%
with open('.files/names.txt')

# %% [markdown]
# ##### re.match()

# %% [markdown]
# ##### re.search()

# %% [markdown]
# ##### Store the String to a Variable

# %% [markdown]
# ### In-Class Exercise #3 <br>
# <p>Print each persons name and twitter handle, using groups, should look like:</p>
# <p>==============<br>
#    Full Name / Twitter<br>
#    ==============</p>
# Derek Hawkins / @derekhawkins
#
#  Erik Sven-Osterberg / @sverik
#
#  Ryan Butz / @ryanbutz
#
#  Example Exampleson / @example
#
#  Ripal Pael / @ripalp
#
#  Darth Vader / @darthvader

# %%
print(re.findall)

twitter=re.findall('[\t](@\w+)', 
if(twitter):
        name=re.findall('(\w+[-\w+]?),(\s\w+)[\t][^,]'
        f_name=name[0][1]
        l_name=name[0][0]
        print(f'{f_name} {l_name} / {twitter[0]}\n')
# Out:
#   Input In [1]
#     print(re.findall[\W][@][a-z]+)
#                       ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# ### Regex project
#
# Use python to read the file regex_test.txt and print the last name on each line using regular expressions and groups (return None for names with no first and last name, or names that aren't properly capitalized)
# ##### Hint: use with open() and readlines()

# %%
import re

# %% [markdown]
# [Abraham Lincoln
# Andrew P Garfield
# Connor Milliken
# Jordan Alexander Williams
# Madonna
# programming is cool]

# %%
with open("./files/regex-test.txt") as file:
    data = file.readlines()

pattern = re.compile(r'([A-Z]{a-z]*)( [A-Z][a-z]*)( [A-Z][a-z]*)*')

for person in data:
    match=pattern.search(person)
    if match:
        if match.group(3) == None:
            print(f"{match.group(1)} {match.group(2)}")
        else:
            print(f"{match.group(1)}  {match.group(2)} {match.group(3)}")
    else: 
        print("none")
# Out:
# none
# none
# none
# none
# none
# none
